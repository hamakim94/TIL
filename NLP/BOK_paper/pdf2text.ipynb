# %%
# !pip3 install pdfminer.six
# Out:
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.6/dist-packages (20200720)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.6/dist-packages (from pdfminer.six) (2.2.2)
# Requirement already satisfied: chardet; python_version > "3.0" in /usr/local/lib/python3.6/dist-packages (from pdfminer.six) (3.0.4)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.6/dist-packages (from pdfminer.six) (3.0)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from cryptography->pdfminer.six) (1.15.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography->pdfminer.six) (1.14.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography->pdfminer.six) (2.20)

# %%
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO
from io import open

def convert_pdf_to_txt():
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec = codec, laparams=laparams)
    fp = open('{}.pdf', 'rb') # 여기에 저장된 url에 대한 response.content를 넣어줘야 함
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos = set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password = password, caching = caching, check_extractable=True):
        interpreter.process_page(page)
    
    text = retstr.getvalue()
    fp.close()
    device.close()
    retstr.close()
    return text

# %%
import requests
from bs4 import BeautifulSoup
file_res = requests.get("https://ssl.pstatic.net/imgstock/upload/research/debenture/1595205128882.pdf") # 여기에 url을 for문으로 돌릴거고
with open('{}.pdf', 'wb') as f: # 여기에 pdf 이름을 정하면 {위에 있는 코드에서 {}.pdf에 넣어주면 돼}
  f.write(file_res.content)

# %%
v = convert_pdf_to_txt()
print(v)
# Out:
# 2020 년 7 월 20 일
#
# 키움증권 리서치센터 투자전략팀
#
# ㅣ채권전략  안예하  02) 3787-5157/ yhahn@kiwoom.com
#
# ㅣRA  김준수  02)3787-3751 / kjs9460@kiwoom.com
#
#
#
# 한은의  성장률  전망  하향에  따른  향후  금리  방향은?
#
# SUMMARY
#
# •한국은행은  지난  금통위에서  2 분기  성장  악화를  고려해  올해  성장률  전망치를  하향  조정할  것이라  예고.
#
# 이에 대응해 한국은행이 어떤 정책을 추가적으로 내놓을 수 있는지에 관심이 높아짐.
#
# •기준금리  인하  가능성은  낮아진  상황에서  한국은행은  가이던스를  제시하고,  국고채  단순매입  확대  등의
#
# 비전통적  통화정책을  활용해  나갈  것으로  전망.  이번  금통위에서  ‘회복세를  확인하기  전까지  완화적인
#
# 정책을 유지하겠다’를 강조하며 일종의 가이던스를  제시했다고 판단함.
#
# •좀더  구체적인  가이던스를  제시하는  방향으로  통화  완화정책을  강화시켜  나가는  한편,  필요시  국고채
#
# 단순매입을 진행하는  방식으로  국고채 금리의  하향 안정화 흐름은  장기화될  것으로  전망.
#
# 한국은행은 어떤 정책을 더 쓸 수 있나
#
# 한국은행은  지난  7 월  16 일  금통위를  통해  올해  성장률을  추가적으로  하향  조정할  가능성을  언급했다.
#
# 5 월에  발표했던  올해  예상  성장률이  3 차  추경을  반영하지  않은  부분임에도  불구하고  추가  하향  조정
#
# 가능성은  기존에  매파적이었던  한국은행의  스탠스를  바꾸는  계기였다고  볼  수  있겠다.
#
#
#
#
#
#
#
# 코로나 19 를  겪으면서  유례없는  유동성  공급  정책을  발표해왔으나,  최근  들어서는  국고채  단순매입에
#
# 대해  비교적  덜  적극적인  모습을  보이고  있으며,  기준금리  또한  추가  인하  가능성을  낮추고  있었다.
#
# 하지만  성장률  하향  조정과  함께  한국은행의  추가  대응  가능성이  높아진  것이다.  그렇다면  한국은행은
#
# 어떤  정책을  추가적으로  내놓을  수  있을까?
#
# 우선  기준금리는  실효하한  수준을  언급하면서  추가  인하  카드를  쉽게  내놓진  않을  것으로  판단한다.
#
# 비록  호주중앙은행과  같은  글로벌  중앙은행과  같이  기준금리를  현수준에서  유지하면서  자산  매입  등을
#
# 통해  완화적인  통화정책을  유지하겠다는  명확한  가이던스를  언급하지는  않았다.  그런  점에서
#
# 기준금리의  추가  인하  가능성이  완전히  차단된  것은  아니라고  볼  수  있다.  그럼에도  코로나 19 의
#
# 전개가  점차적으로  개선될  것이라는  기대가  일부  작용하고  있으며,  하반기  들어서는  성장  회복세도
#
# 기대할  수  있다는  점에서  기준금리의  인하를  통한  추가  정책  대응  가능성은  낮다는  판단이다.
#
# 기준금리  인하  가능성이  낮은  상황에서,  추가적인  완화조치는  ‘가이던스  강화’와  ‘국고채  단순매입
#
# 확대’  등의  비전통적  통화정책이  될  것이다.  특히  이번  금통위에서는  이주열  총재가  ‘국내  경제가
#
#
# 당사는  동  자료를  기관투자자  또는  제3자에게  사전  제공한  사실이  없습니다.
# 동  자료에  게시된  내용들은  본인의  의견을  정확하게  반영하고  있으며,  외부의  부당한  압력이나  간섭없이  작성되었음을  확인합니다.
#
# Compliance Notice
#
#
#
# 고지사항
#
#
#
#
#
# 본  조사분석자료는  당사의  리서치센터가  신뢰할  수  있는  자료  및  정보로부터  얻은  것이나,  당사가  그  정확성이나  완전성을  보장할  수  없고,  통지  없이  의견이  변경될  수
# 있습니다.
# 본  조사분석자료는  유가증권  투자를  위한  정보제공을  목적으로  당사  고객에게  배포되는  참고자료로서,  유가증권의  종류,  종목,  매매의  구분과  방법  등에  관한  의사결정은
#
# 전적으로  투자자  자신의  판단과  책임하에  이루어져야  하며,  당사는  본  자료의  내용에  의거하여  행해진  일제의  투자행위  결과에  대하여  어떠한  책임도  지지  않으며  법적
#
# 분쟁에서  증거로  사용  될  수  없습니다.
#
# 본  조사  분석자료를  무단으로  인용,  복제,  전시,  배포,  전송,  편집,  번역,  출판하는  등의  방법으로  저작권을  침해하는  경우에는  관련법에  의하여  민∙형사상  책임을  지게
# 됩니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
# ,
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2020 년  7 월  20 일  ㅣ  Kiwoom Fixed Income Weekly
#
# 채권전략  안예하  02) 3787-5157
#
# 코로나 19  위기에서  벗어나  회복세를  확인할  때까지는  완화적인  정책을  유지할  필요가  있다’라고
#
# 언급하며  일종의  가이던스를  제시했다고  볼  수  있다.  최근  부동산  시장  과열과  관련해  금융안정  정책
#
# 목표  또한  고려해야하지  않는가라는  질문에  대해  실물  경기  회복에  초점을  두겠다는  의지를  보여준
#
# 것이다.  향후  통화정책회의에서는  가이던스를  좀더  강화하는  방안을  통해  금리  하향  안정화를  추구하는
#
# 쪽을  고려할  수  있겠다.
#
# 더  나아가  한국은행의  적극적  정책  의지는  ‘국고채  단순매입’을  통해  확인할  수  있을  것이다.
#
# 현재로서는  금리가  하향  안정되는  흐름을  보이고  있어  한국은행의  개입  가능성을  낮추고  있지만  한국판
#
# 뉴딜  등  내년도  예산안  등에서도  결국  적자국채  발행으로  인한  수급  불균형  우려는  지속될  것으로
#
# 본다.  특히  올해  성장률은  한국  정부의  대규모  재정지출  확대에도  불구하고  민간  소비와  투자의
#
# 부진으로  인해  마이너스  성장을  피해갈  수  없으며,  내년  또한  아직까지  완연한  회복세를  기대하기는
#
# 제한적이다.  즉,  한국판  뉴딜  정책뿐만  아니더라도  성장  하향을  막기  위해  재정  확장이  지속될  가능성이
#
# 높으며,  한국은행이  국고채  단순매입을  통한  수급  안정  역할을  해낼  것이라는  기대는  여전히  유효하다.
#
# 결국  시장  금리는  기준금리  인하  가능성이  차단되어  있는  상황에서  상승  압력을  받기  보다는
#
# 현수준에서  횡보하는  흐름이  장기화될  것으로  전망한다.  3 차  추경  부분은  선반영되어  있겠으나,  내년도
#
# 예산안  발표  등을  앞두고  국채  발행  증가에  대한  경계감이  유지되면서  금리  커브  또한  플랫되기  보다는
#
# 한국은행의  단순매입  확대  이전까지는  현수준에서  횡보하는  흐름이  좀더  이어질  전망이다.
#
# 한국 수출 증가율과 한국은행 기준금리 및 국고채 금리
#
# 자료: Bloomberg, 키움증권 리서치센터
#
# 한국 경제성장률과 기준금리
#
# 자료: 한국은행, 키움증권 리서치센터
# 주) 2020년 기준금리는 현수준(0.50%), 경제성장률은 5월 전망치 반영
#
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -40-20020400.01.02.03.04.0121314151617181920국고채3년물금리(좌)한국정책금리(좌)한국수출증가율(우)(%)(YOY%)-20246810000102030405060708091011121314151617181920한국경제성장률한국은행기준금리(YOY%, %)
#
#
#
#
#
#
#
#
#
# 지난주 동향
#
# 2020 년  7 월  20 일  ㅣ  Kiwoom Fixed Income Weekly
#
# 채권전략  안예하  02) 3787-5157
#
# 지난주  국고채금리는  코로나 19  백신  및  치료제  기대,  미-중  무역갈등에  대한  우려  등이  혼재되어
#
# 등락하기도  했으나,  예상보다  도비시했던  금통위로  인해  하락했다.  국고채  3 년물은  전주  대비  3.7bp
#
# 하락한  0.812%,  10 년물  금리는  4.9bp  하락한  1.348%로  마감했고  10-3 년  장단기  스프레드는
#
# 53.6bp 로  지난주(54.8bp)보다  축소됐다.
#
# 주  초반  코로나 19 의  글로벌  확산세가  지속되는  가운데  길리어드  사이언스의  백신  관련  긍정적인  소식에
#
# 위험선호  심리가  부각되며  국채금리  상승했다.  또한  정부가  한국판  뉴딜에  160 조원을  투자하겠다고
#
# 발표하면서  초장기물  금리는  상승  압력을  받았지만,  재원  조달에  대한  구체적인  언급이  부재한  가운데
#
# 금통위를  앞두고  한국은행이  공급  불균형을  완화해줄  것이라는  기대  역시  작용해  상승폭은  제한되었다.
#
# 지난주  일본,  유럽  등  주요국  중앙은행은  통화정책회의에서  기준금리를  유지하겠다고  발표했으며,
#
# 한국은행도  만장일치로  기준금리를  동결했다.  이주열  총재는  수출  부진으로  성장률  전망을  하향
#
# 조정하게  된  배경과  코로나 19 의  글로벌  재확산  등으로  불확실성이  높아진  점을  강조했다.  이에  경제가
#
# 회복세를  보이기  전까지는  완화적  정책기조를  이어가겠다고  밝히자  국채금리는  전구간에서  하락했다.
#
# 한편,  한은과  정부  관계부처는  저신용등급  기업에  유동성을  지원하기  위한  회사채  및  CP  매입기구(SPV)
#
# 설립을  발표했다.  다만,  운용  규모와  매입  계획  등  세부적인  내용이  앞서  발표했던  계획안과  큰  차이가
#
# 없다는  점에서  시장에  영향은  제한적이었다.
#
# 주요 국고채 금리 추이
#
#    수익률 곡선 변화
#
# 자료: 금융투자협회, 키움증권 리서치센터
#
#   자료: 금융투자협회, 키움증권 리서치센터
#
# 주요 국고채 금리 스프레드
#
#    미국 국채금리 스프레드 추이
#
#
#
#
#
#
#
#
#
#
#
#
#
# 자료: 금융투자협회, 키움증권 리서치센터
#
#   자료: Bloomberg, 키움증권 리서치센터
#
#
#
#
#
#
#
#
#
#
#
# 3
#
# 0.00.51.01.52.02.53.03.5'16'17'18'19'20한국정책금리국고3년물국고5년물국고10년물국고20년물(%)-2.1 -3.7 -4.5 -4.9 -0.7 -0.9 0.50.70.91.11.31.51.7-6.0-5.0-4.0-3.0-2.0-1.00.01년3년5년10년20년30년주간금리변동(좌)2020-07-172020-07-10(bp)(%)-80-4004080120'16'17'18'19'20국고3Y-기준금리국고5Y-3Y국고10Y-3Y국고30Y-10Y(bp)-50050100150200250300'16'17'18'19'20미국10Y-2Y미국10Y-3M미국30Y-10Y미국30Y-2Y(bp)
