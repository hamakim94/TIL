# %%
from ekonlpy.tag import Mecab

# %%
mecab = Mecab()

# %%
import pandas as pd

# %%
whole = pd.read_csv('C:/Users/User/Desktop/naver.csv')

# %%
whole.head()
# Out:
#   journal_name                          title                  date  \
# 0         이데일리       새한미디어 채권단 600억원대 출자전환 검토  2005.02.27. 오전 11:40
# 1         이데일리        "주택담보대출 만기장기화 서둘러라"-금융硏  2005.02.27. 오후 12:01
# 2         연합뉴스             부산지역 총수신규모 2년연속 감소   2005.02.27. 오전 6:11
# 3         이데일리  외환銀, 지수·환율 연동예금 판매..최고 17.03%  2005.02.27. 오후 12:01
# 4         연합뉴스           외환銀, 지수연동 정기예금 4종 판매  2005.02.27. 오후 12:01
#
#                                              article
# 0  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 1  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 2  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t(부산=연합...
# 3  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 4  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t(서울=연합...

# %%
import re
whole['date'] = whole['date'].apply( lambda x : re.sub('[가-힣]+|[A-z]+','',str(x)).replace(' ','')[:10])

# %%
whole['date']
# Out:
# 0         2005.02.27
# 1         2005.02.27
# 2         2005.02.27
# 3         2005.02.27
# 4         2005.02.27
#              ...
# 206648    2005.01.13
# 206649    2005.01.13
# 206650    2005.01.13
# 206651    2005.01.13
# 206652    2005.01.13
# Name: date, Length: 206653, dtype: object

# %%
whole['contents'] = whole['article']

# %%
whole1 = whole[['date', 'contents']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\nlp\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-f9cea84089eb> in <module>
#       1 whole1 = whole[['date', 'contents']]
# ...

# %%
whole1['contents'][1]
# Out:
# '[\'\\n\\t\', \'\\n\\t\', \'\\n\\n\', \'\\n\', \'\\n\\t\\n\\t[edaily 이정훈기자] 급격한 고령화에 따른 장기 금융자산에 대한 수요 확대에 부응하고 단기에 집중된 주택담보대출 만기를 분산시키기 위해 장기 모기지론으로의 전환을 서두르는 등 만기 장기화에 노력해야한다는 주장이 나왔다.\', \'한국금융연구원 남재현 연구위원은 27일 `고령화에 따른 금융부문의 대응`이라는 연구 보고서를 통해 "고령화가 빠르게 진행되면서 장기 금융자산에 대한 수요가 증가할 것으로 예상돼 주택담보대출을 모기지론으로 전환하고 주택담보부증권(MBS)을 활성화해야한다"고 밝혔다. \', \'남 위원은 "올해에는 주택담보대출 만기가 집중돼 있는 만큼 조기에 모기지론으로 전환을 서둘러야한다"며 "대출금리 인하로 단기 주택담보대출의 전환을 유도하는 한편 주택담보대출중 회수가 어려운 경우 모기지론으로의 대환대출을 해줘야한다"고 주장했다. \', \'특히 그는 주택담보대출 만기 장기화의 대안으로 현재 마련돼 있는 MBS를 활성화할 필요가 있다고 지적했다. \', \'그는 "MBS 발행과 관련된 인센티브를 강화하고 주택저당채권과 MBS의 만기를 20년 이상으로 장기화하는 동시에 변동금리부 채권의 발행도 허용해야할 것"이라고 말했다. \', \'또 "금융기관이나 연기금도 보다 적극적으로 MBS관련 상품을 운용할 수 있도록 해야하며 MBS 공급을 늘리기 위해 주택금융공사의 자본금과 지급보증한도를 대폭적으로 확대할 필요가 있다"고 덧붙였다. \', \'한편 그는 국민연금 적립금이 현행 체계를 유지할 경우 2036년에 최고점에 도달한 후 급격히 하락해 2047년 기금이 소진될 수 있다며 이 기간동안 국민연금으로 인해 국채시장 등에 왜곡이 생기지 않도록 SOC나 해외투자 등 포트폴리오 다변화도 필요하다고 주장했다.\', \'Copyrightⓒ 2000-2005 edaily. All rights reserved.\', \'이정훈 기자 (futures@eda
# ...

# %%
tokens = mpck.tokenize(whole['article'][0].split('.')[2])
tokens
# Out:
# ['채권단/NNG',
#  '서/VV',
#  '면결/NNG',
#  '절차/NNG',
#  '거치/VV',
#  '경영/NNG',
#  '정상화/NNG',
#  '방안/NNG',
#  '채택/NNG',
#  '여부/NNG',
#  '최종/NNG',
#  '결정/NNG',
#  '하/VV']

# %%
whole1['token'] = whole1['contents']
# Out:
# C:\Users\User\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
whole1
# Out:
#               date                                           contents  \
# 0       2005.02.27  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 1       2005.02.27  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 2       2005.02.27  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t(부산=연합...
# 3       2005.02.27  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 4       2005.02.27  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t(서울=연합...
# ...            ...                                                ...
# 206648  2005.01.13  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[뉴욕=ed...
# 206649  2005.01.13  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 206650  2005.01.13  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t(끝)\r'...
# 206651  2005.01.13  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# 206652  2005.01.13  ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '부동...
#
#                                                     token
# 0       ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...
# ...

# %%
from ekonlpy.sentiment import MPCK
mpck = MPCK()
tokens = mpck.tokenize(whole['article'][0].split('.')[0])

# %%
from tqdm.notebook import tqdm

repeat_per=[]
for idx, ff in tqdm(enumerate(whole1['contents'])):
    token_only=[]
    for jdx, fff in enumerate(ff):
        tokk=[]
        tokens= mpck.tokenize(fff)
        if tokens !=[]:
            token_only.append(tokens)
            repeat_per.append([len(list(set(tokens)))/len(tokens),tokens])
    whole1['token'][idx]=token_only

# %%
tokens
# Out:
# ['기자/NNG',
#  '채권단/NNG',
#  '경영/NNG',
#  '정상화/NNG',
#  '위하/VV',
#  '대출/NNG',
#  '금리/NNG',
#  '감면/NNG',
#  '대규모/NNG',
#  '출자전환/NNG',
#  '검토/NNG',
#  '하/XSV']

# %%
ngrams = mpck.ngramize(tokens)
ngrams
# Out:
# ['원화/NNG;급등/NNG', '수출/NNG;부진/NNG', '경영/NNG;여건/NNG;좋/VA']

# %%
ngrams
# Out:
# []

# %%
mpck?

# %%
from ekonlpy.sentiment import MPCK
mpck = MPCK()

# %%
text = whole['article'][0]
text
# Out:
# '[\'\\n\\t\', \'\\n\\t\', \'\\n\\n\', \'\\n\', \'\\n\\t\\n\\t[edaily 오상용기자] 새한미디어(\', \') 채권단은 이 회사의 경영정상화를 위해 대출금리 감면과 600억원대 규모의 출자전환을 검토하고 있다.\', \'27일 금융권에 따르면 주채권은행인 우리은행은 최근 이 같은 내용을 담은 새한미디어 경영정상화 방안을 마련하고 전체 채권금융기관에 안건을 상정했다. 채권단은 서면결의 절차를 거쳐 경영정상화방안의 채택여부를 최종 결정한다.\', \'채권단 관계자는 "최근 환율급락(원화가치 급등)에 따른 수출 부진 등으로 새한미디어의 경영여건이 좋지 않다"면서 "이에 따라 채권단이 600억원대 규모의 출자전환과 함께 7~7.5% 수준인 대출금리를 4~5%대로 감면하는 방안을 검토하고 있다"고 설명했다.\', \'이 관계자는 "서면결의를 통해 채권단 75%의 동의를 얻어야 하는 만큼 `출자전환 및 금리감면안`이 최종 가결될지 여부는 장담할 수 없다"고 말했다. 채권단은 지난 2003년에도 240억원 가량의 출자전환을 실시했었다.\', \'이와함께 새한미디어는 자구방안으로 자회사인 새한마텍을 매각하기로 했다. 새한미디어는 지난해 새한마텍 보유지분 45% 가량을 기업공개(IPO)를 통해 매각하려 했다. 그러나 IPO가 무산되자 지분 직매각을 추진하고 있다.\', \'한편 채권단은 새한미디어 매각을 위해 론스타와 협상을 진행해 왔지만 가격에 대한 채권단내 이견으로 최근 매각이 무산됐다. 채권단 관계자는 "향후 새한미디어 매각은 회사 경영을 정상화한 후 시간을 두고 진행할 것"이라고 말했다.\', \'Copyrightⓒ 2000-2005 edaily. All rights reserved.\', \'오상용 기자 (thug@edaily.co.kr)\', \'\\n\\t\', \'\\n\\t\']'

# %%
text = whole['article'][0] #text 받기
print(text)
tokens = mpck.tokenize(text)
tokens
# Out:
# ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edaily 오상용기자] 새한미디어(', ') 채권단은 이 회사의 경영정상화를 위해 대출금리 감면과 600억원대 규모의 출자전환을 검토하고 있다.', '27일 금융권에 따르면 주채권은행인 우리은행은 최근 이 같은 내용을 담은 새한미디어 경영정상화 방안을 마련하고 전체 채권금융기관에 안건을 상정했다. 채권단은 서면결의 절차를 거쳐 경영정상화방안의 채택여부를 최종 결정한다.', '채권단 관계자는 "최근 환율급락(원화가치 급등)에 따른 수출 부진 등으로 새한미디어의 경영여건이 좋지 않다"면서 "이에 따라 채권단이 600억원대 규모의 출자전환과 함께 7~7.5% 수준인 대출금리를 4~5%대로 감면하는 방안을 검토하고 있다"고 설명했다.', '이 관계자는 "서면결의를 통해 채권단 75%의 동의를 얻어야 하는 만큼 `출자전환 및 금리감면안`이 최종 가결될지 여부는 장담할 수 없다"고 말했다. 채권단은 지난 2003년에도 240억원 가량의 출자전환을 실시했었다.', '이와함께 새한미디어는 자구방안으로 자회사인 새한마텍을 매각하기로 했다. 새한미디어는 지난해 새한마텍 보유지분 45% 가량을 기업공개(IPO)를 통해 매각하려 했다. 그러나 IPO가 무산되자 지분 직매각을 추진하고 있다.', '한편 채권단은 새한미디어 매각을 위해 론스타와 협상을 진행해 왔지만 가격에 대한 채권단내 이견으로 최근 매각이 무산됐다. 채권단 관계자는 "향후 새한미디어 매각은 회사 경영을 정상화한 후 시간을 두고 진행할 것"이라고 말했다.', 'Copyrightⓒ 2000-2005 edaily. All rights reserved.', '오상용 기자 (thug@edaily.co.kr)', '\n\t', '\n\t']
# ['기자/NNG',
#  '채권단/NNG',
#  '경영/NNG',
#  '정상화/NNG',
#  '위하/VV',
#  '대출/NNG',
#  '금리/NNG',
#  '감면/NNG',
# ...

# %%
mpck.ngramize(tokens)
# Out:
# ['경영/NNG;여건/NNG;좋/VA', '원화/NNG;급등/NNG', '수출/NNG;부진/NNG']

# %%
Callrate_labeling = pd.read_csv('Callrate_labeling.csv')
Callrate_labeling = Callrate_labeling.set_index('date')
Callrate_labeling
# Out:
#            Labeling
# date
# 2017.12.31       up
# 2017.12.30     down
# 2017.12.29       up
# 2017.12.28       up
# 2017.12.27       up
# ...             ...
# 2005.01.05     down
# 2005.01.04       up
# 2005.01.03       up
# 2005.01.02       up
# 2005.01.01       up
#
# [4748 rows x 1 columns]

# %%
whole['len']=whole['date'].apply(lambda x: len(x))

# %%
whole[whole['len']!=10]
# Out:
#        journal_name                                   title date  \
# 83             이데일리  [IR라운지]中企 대출 규모 전체 78%…'가계대출 규제' 끄떡없어요   16
# 85             이데일리                내년 44만가구 ‘입주 폭탄’…역전세난 오나  261
# 86             이데일리    [블랙홀된 암호화폐]②하루 10兆 거래..테마株도 `미친 존재감`   31
# 107            이데일리                     내년 신혼부부 전용 대출상품 나온다  261
# 148            이데일리         하반기 부동산 보유세 개편 추진…인상 땐 다주택자 직격탄   11
# ...             ...                                     ...  ...
# 194720         연합뉴스                                     NaN
# 195682         연합뉴스                                     NaN
# 200378         연합뉴스                                     NaN
# 200954         연합뉴스                                     NaN
# 202195         연합뉴스                                     NaN
#
#                                                   article  len
# 83      ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...    2
# 85      ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...    3
# ...

# %%
nnaver=pd.read_csv('naver.csv')

# %%
nnaver.iloc[83]
# Out:
# journal_name                                                 이데일리
# title                      [IR라운지]中企 대출 규모 전체 78%…'가계대출 규제' 끄떡없어요
# date                                                        A16면
# article         ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t', '[이...
# Name: 83, dtype: object

# %%
labeled = whole.merge(Callrate_labeling,on='date')

# %%
def compare_append(txt):
    txt['Polarity'] = ''
    Hawkish = []
    Dovish = []
    Grey = []
    for i in range(len(txt)):
        temp_date = txt['date'][i]
        if Callrate_labeling.loc[str(temp_date)][0] == 'up':
            Hawkish.append(txt['article'][i])#content로 바꿔주기
            txt['Polarity'][i] = 'H'
        elif Callrate_labeling.loc[str(temp_date)][0] == 'down':
            Dovish.append(txt['article'][i])#content로 바꿔주기
            txt['Polarity'][i]='D'
        else:
            Grey.append(txt['article'][i])#content로 바꿔주기
            txt['Polarity'][i]='N'
    Labeled = txt
    return Labeled, 'Hakish:', Hawkish, 'Dovish: ', Dovish, 'Grey: ',Grey#Labled를 따로 받을 수 있게 해주자

# %%
labeled
# Out:
#        journal_name                          title        date  \
# 0              이데일리       새한미디어 채권단 600억원대 출자전환 검토  2005.02.27
# 1              이데일리        "주택담보대출 만기장기화 서둘러라"-금융硏  2005.02.27
# 2              연합뉴스             부산지역 총수신규모 2년연속 감소  2005.02.27
# 3              이데일리  외환銀, 지수·환율 연동예금 판매..최고 17.03%  2005.02.27
# 4              연합뉴스           외환銀, 지수연동 정기예금 4종 판매  2005.02.27
# ...             ...                            ...         ...
# 204034         이데일리     민노당 "카드사 잘못있는 실업자 등도 채무탕감"  2005.01.16
# 204035         이데일리      달러/엔 한때 101엔대로 급락..5년래 최저  2005.01.15
# 204036         연합뉴스           전북은행 中企 설자금 500억원 지원  2005.01.15
# 204037         이데일리            뉴욕 동반반등..지표호조에 반발매수  2005.01.15
# 204038         연합뉴스  <표> 은행 금전신탁배당률.정기예금 금리(1.14일)  2005.01.15
#
#                                                   article  len Polarity  \
# 0       ['\n\t', '\n\t', '\n\n', '\n', '\n\t\n\t[edail...   10        H
# ...

# %%
from collections import defaultdict
corpus = defaultdict(lambda : [0,0])

# %%
from collections import defaultdict
corpus = defaultdict(lambda : [0,0]) # 왼쪽이 Hawkish, 오른쪽이 Dovish라고 일단 생각

from tqdm.notebook import tqdm

for i in tqdm(range(len(labeled['article']))): # 규호의 Label까지 merge 한 데이터의 제목, 규호왈 'contents'

    if labeled.iloc[i]['Labeling'] == 'up':
        tokens = mpck.tokenize(labeled.iloc[i]['article']) 
        for ngrams in mpck.ngramize(tokens):
                corpus[ngrams][0] += 1
        for token in tokens:
            corpus[token][0] += 1
            
    elif labeled.iloc[i]['Labeling'] == 'down':
        tokens = mpck.tokenize(labeled.iloc[i]['article'])
        for ngrams in mpck.ngramize(tokens):
                corpus[ngrams][1] += 1
        for token in tokens:
            corpus[token][1] += 1
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-234-81e90876c7fb> in <module>
#       8     if labeled.iloc[i]['Labeling'] == 'up':
#       9         tokens = mpck.tokenize(labeled.iloc[i]['article'])
# ---> 10         for ngrams in mpck.ngramize(tokens):
#      11                 corpus[ngrams][0] += 1
#      12         for token in tokens:
#
# ~\TIL\NLP\논문\eKoNLPy-master\ekonlpy\sentiment\mpck.py in ngramize(self, tokens, keep_overlapping_ngram)
#      85         for pos in range(len(tokens)):
#      86             for gram in range(self._min_ngram, self._ngram + 1):
# ---> 87                 token = self.get_ngram(tokens, pos, gram)
#      88                 if token:
#      89                     if token in self._vocab:
#
# ~\TIL\NLP\논문\eKoNLPy-master\ekonlpy\sentiment\mpck.py in get_ngram(self, tokens, pos, gram)
# ...

# %%
corpus
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'경영/NNG;여건/NNG;좋/VA': [3, 2],
#              '원화/NNG;급등/NNG': [6, 7],
#              '수출/NNG;부진/NNG': [212, 211],
#              '기자/NNG': [15547, 16628],
#              '채권단/NNG': [210, 158],
#              '경영/NNG': [1002, 962],
#              '정상화/NNG': [1058, 1035],
#              '위하/VV': [9857, 10055],
#              '대출/NNG': [12991, 14107],
#              '금리/NNG': [80192, 91370],
#              '감면/NNG': [258, 236],
#              '대규모/NNG': [1272, 1354],
#              '출자전환/NNG': [83, 72],
#              '검토/NNG': [1305, 1430],
#              '하/XSV': [92805, 97373],
#              '금융/NNG': [7131, 7342],
#              '따르/VV': [16784, 18012],
#              '주채권은행/NNG': [15, 25],
#              '같/VA': [9503, 10289],
#              '내용/NNG': [1823, 1841],
#              '담/VV': [571, 681],
#              '방안/NNG': [2180, 2201],
#              '마련/NNG': [1894, 1902],
#              '채권/NNG': [8876, 9772],
# ...

# %%
mpck.tokenize(labeled.iloc[0]['article'])
# Out:
# ['기자/NNG',
#  '채권단/NNG',
#  '경영/NNG',
#  '정상화/NNG',
#  '위하/VV',
#  '대출/NNG',
#  '금리/NNG',
#  '감면/NNG',
#  '대규모/NNG',
#  '출자전환/NNG',
#  '검토/NNG',
#  '하/XSV',
#  '금융/NNG',
#  '따르/VV',
#  '주채권은행/NNG',
#  '같/VA',
#  '내용/NNG',
#  '담/VV',
#  '경영/NNG',
#  '정상화/NNG',
#  '방안/NNG',
#  '마련/NNG',
#  '하/XSV',
#  '채권/NNG',
#  '금융기관/NNG',
#  '안건/NNG',
#  '상정/NNG',
#  '하/VV',
#  '채권단/NNG',
#  '서/VV',
#  '면결/NNG',
#  '절차/NNG',
#  '거치/VV',
#  '경영/NNG',
#  '정상화/NNG',
#  '방안/NNG',
#  '채택/NNG',
#  '여부/NNG',
#  '최종/NNG',
#  '결정/NNG',
#  '하/VV',
#  '채권단/NNG',
#  '관계자/NNG',
#  '환율/NNG',
#  '급락/NNG',
#  '원화/NNG',
#  '급등/NNG',
#  '따르/VV',
#  '수출/NNG',
#  '부진/NNG',
#  '경영/NNG',
#  '여건/NNG',
#  '좋/VA',
#  '않/VX',
#  '채권단/NNG',
#  '대규모/NNG',
#  '출자전환/NNG',
#  '함께/MAG',
#  '수준/NNG',
#  '대출/NNG',
#  '금리/NNG',
#  '감면/NNG',
#  '하/XSV',
#  '방안/NNG',
#  '검토/NNG',
#  '하/XSV',
#  '설명/NNG',
#  '하/VV',
#  '관계자/NNG',
#  '서면/NNG',
#  '결의/NNG',
#  '통하/VV',
#  '채권단/NNG',
#  '동의/NNG',
#  '얻/VV',
#  '하/VV',
#  '출자전환/NNG',
# ...

# %%
labeled[labeled['Labeling']=='-']
# Out:
#        journal_name                                    title        date  \
# 93             연합뉴스                   뉴욕증시, 연준 의장 발언 속 상승 출발  2016.02.10
# 94             연합뉴스      보험업계 신회계제도 준비 '미적'…당국 "내달까지 계획서 내라"  2016.02.10
# 95             연합뉴스          닛케이지수 15,000 붕괴 가능성…日 증시 왜 추락하나  2016.02.10
# 96             연합뉴스  최상목 기재차관 "북한 도발 후 연휴 금융시장 특이동향 없었다"(종합)  2016.02.10
# 97             연합뉴스     일본 닛케이 낙폭 2.6%대로 확대…장중 16,000 붕괴(종합)  2016.02.10
# ...             ...                                      ...         ...
# 203807         이데일리             채권금리, 장마감 후 급락..입찰 축소 영향(마감)  2005.01.12
# 203808         연합뉴스                   <채권> 금리 소폭 상승..투자심리 약세  2005.01.12
# 203809         이데일리                  HSBC "中 상반기중 27bp 금리인상"  2005.01.12
# 203810         이데일리               KB자산운용 백경호 사장 "現 금리상승 일시적"  2005.01.12
# 203811         연합뉴스                `개인 투자자 잡아라'..증거금.대출금리 인하  2005.01.12
#
#                                                   article  len Polarity  \
# ...

# %%
import numpy as np
n
# Out:
# array(defaultdict(<function <lambda> at 0x000001C1D373B048>, {'기자/NNG': [11, 0], '경영/NNG;여건/NNG;좋/VA': [142, 0], '원화/NNG;급등/NNG': [142, 0], '수출/NNG;부진/NNG': [142, 0], '채권단/NNG': [8, 0], '경영/NNG': [5, 0], '정상화/NNG': [4, 0], '위하/VV': [5, 0], '대출/NNG': [36, 0], '금리/NNG': [60, 0], '감면/NNG': [3, 0], '대규모/NNG': [2, 0], '출자전환/NNG': [4, 0], '검토/NNG': [2, 0], '하/XSV': [25, 0], '금융/NNG': [3, 0], '따르/VV': [9, 0], '주채권은행/NNG': [1, 0], '같/VA': [1, 0], '내용/NNG': [1, 0], '담/VV': [1, 0], '방안/NNG': [3, 0], '마련/NNG': [2, 0], '채권/NNG': [3, 0], '금융기관/NNG': [8, 0], '안건/NNG': [1, 0], '상정/NNG': [1, 0], '하/VV': [64, 0], '서/VV': [1, 0], '면결/NNG': [1, 0], '절차/NNG': [1, 0], '거치/VV': [1, 0], '채택/NNG': [1, 0], '여부/NNG': [2, 0], '최종/NNG': [2, 0], '결정/NNG': [2, 0], '관계자/NNG': [3, 0], '환율/NNG': [5, 0], '급락/NNG': [1, 0], '원화/NNG': [1, 0], '급등/NNG': [2, 0], '수출/NNG': [1, 0], '부진/NNG': [2, 0], '여건/NNG': [1, 0], '좋/VA': [2, 0], '않/VX': [3, 0], '함께/MAG': [3, 0], '수준/NNG': [4, 0], '설명/NNG': [4, 0], '서면/NNG': [1, 0], '결의/
# ...
