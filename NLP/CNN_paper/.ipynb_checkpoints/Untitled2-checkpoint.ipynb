# %%
import functions as fc
training_sentences, testing_sentences, training_labels, testing_labels = fc.load_data('.')
training_padded, training_labels, testing_padded, testing_labels = fc.tokenize_and_pad_model3('.')
model, history = fc.model3_context('.') # 여기서 파라미터 수정 가능
fc.plot_loss_graphs(history)
fc.plot_graphs
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 30, 100)      2000000     input_3[0][0]
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 30, 100)      2000000     input_3[0][0]
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 30, 100)      2000000     input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 28, 100)      30100       embedding_6[0][0]
# ...
