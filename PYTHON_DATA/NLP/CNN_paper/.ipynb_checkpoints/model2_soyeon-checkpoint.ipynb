#         8.20553601e-01,  3.45031060e-02, -6.68196499e-01,  1.61060047e+00,
#         2.65534937e-01,  1.24002767e+00,  1.61996996e+00, -2.00592852e+00,
#         6.29359245e-01, -1.35131919e+00,  2.76473194e-01, -4.46986228e-01,
#        -2.53276855e-01,  1.53764343e+00,  6.05187058e-01,  6.05335459e-02,
#        -5.39341196e-02,  5.79544425e-01,  4.22562987e-01, -1.97442901e+00,
#         9.51142833e-02, -9.14012849e-01, -5.47553599e-01, -5.43647826e-01,
#         3.91458243e-01, -1.23735213e+00, -1.14660323e+00,  1.74715757e+00,
#         6.80540562e-01,  2.29177308e+00,  6.59082353e-01,  1.84193575e+00,
#        -1.89989954e-01, -9.19043645e-02,  1.62832558e+00,  8.45791772e-02,
#        -1.06711626e-01, -1.12618256e+00, -1.31909204e+00,  2.38393173e-01,
#        -5.44293463e-01,  2.38525525e-01, -2.90395641e+00, -5.06984890e-01,
#        -6.50369704e-01, -1.33505285e+00,  6.70029342e-01, -3.81612420e-01,
#        -2.00835848e+00,  1.00355136e+00, -6.54984117e-01,  1.10105038e+00,
#         1.05699301e-01,  6.22650683e-01,  4.73337799e-01, -2.59310812e-01,
#         4.99202013e-01,  7.38488376e-01, -1.88814163e+00,  7.97092259e-01,
#         1.51610231e+00,  2.06020311e-01, -1.39211369e+00, -2.56290108e-01],
#       dtype=float32)

# %%
print(ko_model.wv.most_similar("최민식"))
# Out:
# [('한석규', 0.9022693634033203), ('이민호', 0.8778703808784485), ('이미숙', 0.8716947436332703), ('설경구', 0.8695714473724365), ('김명민', 0.8679181933403015), ('이정재', 0.863978385925293), ('정재영', 0.8619986176490784), ('메릴', 0.8613458871841431), ('이주승', 0.861168622970581), ('공리', 0.8594560027122498)]

# %% [markdown]
# ## Train Test Data 불러오기

# %%
import pickle
import pandas as pd
test = pd.read_pickle("token_test_data.pkl")
train = pd.read_pickle("token_train_data.pkl")

# train, test 명시 
training_sentences = train['tokens']
testing_sentences = test['tokens']

training_labels = train['labels']
testing_labels = test['labels']

training_sentences.shape, testing_sentences.shape, training_labels.shape, testing_labels.shape
# Out:
# ((145791,), (48995,), (145791,), (48995,))

# %%
training_sentences
# Out:
# 0                                  [더빙, 진짜, 짜증나다, 목소리]
# 1                 [흠, 포스터, 보고, 초딩, 영화, 줄, 오버, 연기, 가볍다]
# 2                                 [무재, 밓었, 다그, 래서, 추천]
# 3                 [교도소, 이야기, 구먼, 솔직하다, 재미, 없다, 평점, 조정]
# 4         [몬페, 의, 익살스럽다, 연기, 영화, 스파이더맨, 커스틴, 던스트, 이쁘다]
#                               ...
# 145786                                 [인간, 문제, 소, 죄인]
# 145787                                        [평점, 낮다]
# 145788                  [이, 뭐, 한국인, 먹거리, 필리핀, 혼혈, 착하다]
# 145789                 [청춘, 영화, 최고봉, 방황, 우울하다, 날, 자화상]
# 145790                        [한국, 영화, 최초, 수간, 내용, 영화]
# Name: tokens, Length: 145791, dtype: object

# %% [markdown]
# ## Tokenize / Padding

# %%
# 파라미터 명시 
vocab_size = 20000
embedding_dim = 200
max_length = 30
truct_type = 'post'
padding_type = 'post'
oov_tok = '<OOV>'

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index


word_index, len(word_index)
# Out:
# ({'<OOV>': 1,
#   '영화': 2,
#   '없다': 3,
#   '있다': 4,
#   '좋다': 5,
#   '재밌다': 6,
#   '정말': 7,
#   '것': 8,
#   '같다': 9,
#   '진짜': 10,
#   '아니다': 11,
#   '점': 12,
#   '이': 13,
#   '연기': 14,
#   '평점': 15,
#   '최고': 16,
#   '왜': 17,
#   '스토리': 18,
#   '생각': 19,
#   '드라마': 20,
#   '감동': 21,
#   '사람': 22,
#   '보고': 23,
#   '말': 24,
#   '이렇다': 25,
#   '아깝다': 26,
#   '더': 27,
#   '배우': 28,
#   '때': 29,
#   '감독': 30,
#   '거': 31,
#   '내': 32,
#   '재미있다': 33,
#   '뭐': 34,
#   '시간': 35,
#   '재미': 36,
#   '내용': 37,
#   '그냥': 38,
#   '좀': 39,
#   '그': 40,
#   '지루하다': 41,
#   '재미없다': 42,
#   '쓰레기': 43,
#   '수': 44,
#   '그렇다': 45,
#   '작품': 46,
#   '사랑': 47,
#   '나': 48,
#   '하나': 49,
#   '다시': 50,
#   '마지막': 51,
#   '볼': 52,
#   '이다': 53,
#   '정도': 54,
#   '처음': 55,
#   '완전': 56,
#   '많다': 57,
#   '장면': 58,
#   '액션': 59,
#   '주인공': 60,
#   '안되다': 61,
#   '돈': 62,
#   '최악': 63,
#   '이야기': 64,
#   '지금': 65,
#   '걸': 66,
#   '느낌': 67,
#   '연출': 68,
#   '임': 69,
#   '끝': 70,
#   '듯': 71,
#   '좋아하다': 72,
#   '명작': 73,
#   '별로': 74,
#   '년': 75,
#   '역시': 76,
#   '개': 77,
#   '이해': 78,
#   '안': 79,
#   '이영화': 80,
#   '괜찮다': 81,
#   '또': 82,
#   '때문': 83,
#   '여자': 84,
#   '아름답다': 85,
#   '꼭': 86,
#   '보기': 87,
#   '기억': 88,
#   '결말': 89,
#   '편': 90,
#   '난': 91,
#   '분': 92,
#   '어떻다': 93,
#   '중': 94,
#   '아쉽다': 95,
#   '인생': 96,
#   '마음': 97,
#   '소재': 98,
#   '뻔하다': 99,
#   '못': 100,
#   '애': 101,
#   '수준': 102,
#   '무섭다': 103,
#   '현실': 104,
#   '한번': 105,
#   '가장': 106,
#   '반전': 107,
#   '매력': 108,
#   '전개': 109,
#   '남자': 110,
#   '한국': 111,
#   '가슴': 112,
#   '낮다': 113,
#   '아이': 114,
#   '슬프다': 115,
#   '높다': 116,
#   '유치하다': 117,
#   '음악': 118,
#   '알': 119,
#   '멋지다': 120,
#   '원작': 121,
#   '저': 122,
#   '줄': 123,
#   '게': 124,
#   '인간': 125,
#   '솔직하다': 126,
#   '우리': 127,
#   '추천': 128,
#   '눈물': 129,
#   '무슨': 130,
#   '만': 131,
#   '속': 132,
#   '함': 133,
#   '자체': 134,
#   '번': 135,
#   '야하다': 136,
#   '눈': 137,
#   '짜증나다': 138,
#   '코미디': 139,
#   '캐릭터': 140,
#   '대한': 141,
#   '움': 142,
#   '뭔가': 143,
#   '이상': 144,
#   '대박': 145,
#   '전혀': 146,
#   '이쁘다': 147,
#   '도': 148,
#   '연기력': 149,
#   '여운': 150,
#   '미치다': 151,
#   '모두': 152,
#   '개봉': 153,
#   '공감': 154,
#   '일본': 155,
#   '기대': 156,
#   '기대하다': 157,
#   '시리즈': 158,
#   '중간': 159,
#   '영상': 160,
#   '부분': 161,
#   '아주': 162,
#   '모습': 163,
#   '귀엽다': 164,
#   '제목': 165,
#   '계속': 166,
#   '가족': 167,
#   '내내': 168,
#   '전': 169,
#   '보지': 170,
#   '뿐': 171,
#   '진심': 172,
#   '다른': 173,
#   '무엇': 174,
#   '몰입': 175,
#   '실망': 176,
#   '표현': 177,
#   '후': 178,
#   '급': 179,
#   '기분': 180,
#   '대단하다': 181,
#   '별': 182,
#   '작가': 183,
#   '잔잔하다': 184,
#   '요': 185,
#   '이제': 186,
#   '위': 187,
#   '요즘': 188,
#   '공포': 189,
#   '스릴러': 190,
#   '감': 191,
#   '긴장감': 192,
#   '개인': 193,
#   '용': 194,
#   '모든': 195,
#   '잼': 196,
#   '조금': 197,
#   '애니': 198,
#   '대사': 199,
#   '알바': 200,
#   '이유': 201,
#   '제대로': 202,
#   '삶': 203,
#   '극장': 204,
#   '건': 205,
#   '점도': 206,
#   '노래': 207,
#   '욕': 208,
#   '굿': 209,
#   '점수': 210,
#   '시작': 211,
#   '막장': 212,
#   '나름': 213,
#   '예쁘다': 214,
#   '이상하다': 215,
#   '깊다': 216,
#   '제일': 217,
#   '차라리': 218,
#   '놈': 219,
#   '친구': 220,
#   '영화로': 221,
#   '당시': 222,
#   '노잼': 223,
#   '어설프다': 224,
#   '의미': 225,
#   '절대': 226,
#   '일': 227,
#   '기': 228,
#   '위해': 229,
#   '류': 230,
#   '세상': 231,
#   '따뜻하다': 232,
#   '미국': 233,
#   '훌륭하다': 234,
#   '공포영화': 235,
#   '년대': 236,
#   '도대체': 237,
#   '웃음': 238,
#   '제': 239,
#   '설정': 240,
#   '앞': 241,
#   '짱': 242,
#   '힘들다': 243,
#   '초반': 244,
#   '다르다': 245,
#   '물': 246,
#   '뭘': 247,
#   '우리나라': 248,
#   '출연': 249,
#   '수작': 250,
#   '해': 251,
#   '싫다': 252,
#   '답답하다': 253,
#   '사실': 254,
#   '추억': 255,
#   '한국영': 256,
#   '가지': 257,
#   '멋있다': 258,
#   '남': 259,
#   '시나리오': 260,
#   '신선하다': 261,
#   '아프다': 262,
#   '관객': 263,
#   '소리': 264,
#   '분위기': 265,
#   '필요없다': 266,
#   '로': 267,
#   '팬': 268,
#   '시대': 269,
#   '장난': 270,
#   '명': 271,
#   '지루함': 272,
#   '어이없다': 273,
#   '나쁘다': 274,
#   '살': 275,
#   '자신': 276,
#   '감정': 277,
#   '졸작': 278,
#   '엔딩': 279,
#   '준': 280,
#   '영화관': 281,
#   '안타깝다': 282,
#   '오늘': 283,
#   '엄마': 284,
#   '봄': 285,
#   '제발': 286,
#   '정신': 287,
#   '접': 288,
#   '인상': 289,
#   '부족하다': 290,
#   '스럽다': 291,
#   '더럽다': 292,
#   '더빙': 293,
#   '포스터': 294,
#   '캐스팅': 295,
#   '최고다': 296,
#   '라면': 297,
#   '평가': 298,
#   '문제': 299,
#   '코믹': 300,
#   '얼마나': 301,
#   '애니메이션': 302,
#   '어색하다': 303,
#   '몰입도': 304,
#   '티비': 305,
#   '기도': 306,
#   '배경': 307,
#   '망하다': 308,
#   '대해': 309,
#   '유쾌하다': 310,
#   '데': 311,
#   '뒤': 312,
#   '맘': 313,
#   '킬링타임': 314,
#   '음': 315,
#   '스릴': 316,
#   '만화': 317,
#   '충격': 318,
#   '얘기': 319,
#   '완벽하다': 320,
#   '전쟁': 321,
#   '존나': 322,
#   '진부하다': 323,
#   '등': 324,
#   '즐겁다': 325,
#   '책': 326,
#   '개연': 327,
#   '예술': 328,
#   '머리': 329,
#   '갈수록': 330,
#   '질': 331,
#   '어디': 332,
#   '얼굴': 333,
#   '매우': 334,
#   '웃기': 335,
#   '머': 336,
#   '후회': 337,
#   '이름': 338,
#   '영화인': 339,
#   '옛날': 340,
#   '구성': 341,
#   '행복하다': 342,
#   '적': 343,
#   '집중': 344,
#   '이후': 345,
#   '장르': 346,
#   '꽤': 347,
#   '집': 348,
#   '주연': 349,
#   '의': 350,
#   '새롭다': 351,
#   '멀다': 352,
#   '날': 353,
#   '다큐': 354,
#   '누구': 355,
#   '시즌': 356,
#   '상황': 357,
#   '건가': 358,
#   '그것': 359,
#   '언제': 360,
#   '짜증': 361,
#   '억지': 362,
#   '씬': 363,
#   '예전': 364,
#   '충분하다': 365,
#   '글': 366,
#   '후반': 367,
#   '비': 368,
#   '역사': 369,
#   '다운': 370,
#   '강추': 371,
#   '걸작': 372,
#   '궁금하다': 373,
#   '불쌍하다': 374,
#   '여기': 375,
#   '누가': 376,
#   '진': 377,
#   '약간': 378,
#   '자기': 379,
#   '두': 380,
#   '소름': 381,
#   '인물': 382,
#   '실화': 383,
#   '해도': 384,
#   '발연기': 385,
#   '그대로': 386,
#   '밉다': 387,
#   '방송': 388,
#   '심하다': 389,
#   '시절': 390,
#   '만점': 391,
#   '잔인하다': 392,
#   '회': 393,
#   '비디오': 394,
#   '대체': 395,
#   '순수하다': 396,
#   '비슷하다': 397,
#   '작': 398,
#   '어렵다': 399,
#   '니': 400,
#   '소설': 401,
#   '한마디': 402,
#   '로맨스': 403,
#   '사회': 404,
#   '아들': 405,
#   '부': 406,
#   '비교': 407,
#   '필요하다': 408,
#   '초딩': 409,
#   '감성': 410,
#   '판': 411,
#   '네이버': 412,
#   '다음': 413,
#   '를': 414,
#   '보': 415,
#   '여배우': 416,
#   '여주': 417,
#   '전체': 418,
#   '간만': 419,
#   '상당하다': 420,
#   '편이': 421,
#   '나이': 422,
#   '사랑스럽다': 423,
#   '당하다': 424,
#   '꿈': 425,
#   '코': 426,
#   '성룡': 427,
#   '굉장하다': 428,
#   '동안': 429,
#   '혼자': 430,
#   '순간': 431,
#   '교훈': 432,
#   '삼류': 433,
#   '은': 434,
#   '존재': 435,
#   '힘': 436,
#   '바로': 437,
#   '주제': 438,
#   '진정하다': 439,
#   '목소리': 440,
#   '년도': 441,
#   '안보': 442,
#   '화려하다': 443,
#   '죽': 444,
#   '당신': 445,
#   '거의': 446,
#   '너': 447,
#   '몇번': 448,
#   '낭비': 449,
#   '가볍다': 450,
#   '년전': 451,
#   '질질': 452,
#   '독특하다': 453,
#   '나라': 454,
#   '엄청나다': 455,
#   '줄거리': 456,
#   '성하다': 457,
#   '자': 458,
#   '의도': 459,
#   '딸': 460,
#   '아버지': 461,
#   '좀비': 462,
#   '판타지': 463,
#   '이번': 464,
#   '갑자기': 465,
#   '어른': 466,
#   '전부': 467,
#   '점주': 468,
#   '상영': 469,
#   '시청률': 470,
#   '흥미롭다': 471,
#   '피': 472,
#   '실제': 473,
#   '넘치다': 474,
#   '신': 475,
#   '평론가': 476,
#   '곳': 477,
#   '맛': 478,
#   '만하': 479,
#   '재': 480,
#   '필요': 481,
#   '땜': 482,
#   '제작': 483,
#   '막': 484,
#   '바': 485,
#   '점점': 486,
#   '한편': 487,
#   '그녀': 488,
#   '화면': 489,
#   '극장판': 490,
#   '초': 491,
#   '중국': 492,
#   '답': 493,
#   '각본': 494,
#   '간다': 495,
#   '볼때': 496,
#   '억지스럽다': 497,
#   '밑': 498,
#   '평': 499,
#   '관람': 500,
#   '이하': 501,
#   '스타일': 502,
#   '란': 503,
#   '세계': 504,
#   '선택': 505,
#   '선': 506,
#   '성우': 507,
#   '요소': 508,
#   '복수': 509,
#   '항상': 510,
#   '일단': 511,
#   '굳다': 512,
#   '둘': 513,
#   '똥': 514,
#   '가치': 515,
#   '뻔': 516,
#   '흥행': 517,
#   '힘드다': 518,
#   '너무하다': 519,
#   '참고': 520,
#   '그때': 521,
#   '더욱': 522,
#   '확실하다': 523,
#   '영': 524,
#   '드': 525,
#   '불편하다': 526,
#   '면': 527,
#   '아빠': 528,
#   '평범하다': 529,
#   '수가': 530,
#   '역대': 531,
#   '거기': 532,
#   '발': 533,
#   '완성': 534,
#   '편집': 535,
#   '단순하다': 536,
#   '상미': 537,
#   '전형': 538,
#   '멜로': 539,
#   '허무하다': 540,
#   '거지': 541,
#   '새끼': 542,
#   '짧다': 543,
#   '세': 544,
#   '화이팅': 545,
#   '역': 546,
#   '어이': 547,
#   '술': 548,
#   '탄탄하다': 549,
#   '진행': 550,
#   '불륜': 551,
#   '구': 552,
#   '엉망': 553,
#   '예상': 554,
#   '병맛': 555,
#   '개그': 556,
#   '잠': 557,
#   '사건': 558,
#   '낫다': 559,
#   '중반': 560,
#   '지겹다': 561,
#   '미화': 562,
#   '소중하다': 563,
#   '그게': 564,
#   '설명': 565,
#   '똑같다': 566,
#   '과거': 567,
#   '또한': 568,
#   '키': 569,
#   '적당하다': 570,
#   '프랑스': 571,
#   '중요하다': 572,
#   '화보': 573,
#   '꿀잼': 574,
#   '훈훈하다': 575,
#   '봣': 576,
#   '도저히': 577,
#   '손': 578,
#   '노력': 579,
#   '흥미진진': 580,
#   '몇': 581,
#   '댓글': 582,
#   '그래픽': 583,
#   '흥미': 584,
#   '거리': 585,
#   '죽음': 586,
#   '원래': 587,
#   '취향': 588,
#   '티': 589,
#   '무조건': 590,
#   '몸': 591,
#   '리': 592,
#   '식상하다': 593,
#   '척': 594,
#   '화가': 595,
#   '뛰어나다': 596,
#   '마르다': 597,
#   '자극': 598,
#   '역겹다': 599,
#   '배': 600,
#   '감상': 601,
#   '울': 602,
#   '한심하다': 603,
#   '학교': 604,
#   '길다': 605,
#   '자꾸': 606,
#   '액션영화': 607,
#   '관': 608,
#   '아저씨': 609,
#   '예고편': 610,
#   '오히려': 611,
#   '바보': 612,
#   '결혼': 613,
#   '심리': 614,
#   '용도': 615,
#   '다가': 616,
#   '속편': 617,
#   '게임': 618,
#   '연기자': 619,
#   '보이': 620,
#   '마무리': 621,
#   '터': 622,
#   '무': 623,
#   '잘만': 624,
#   '강하다': 625,
#   '관계': 626,
#   '천재': 627,
#   '법': 628,
#   '미안하다': 629,
#   '참신하다': 630,
#   '억지로': 631,
#   '표정': 632,
#   '아무': 633,
#   '과': 634,
#   '귀신': 635,
#   '땐': 636,
#   '최근': 637,
#   '전설': 638,
#   '현재': 639,
#   '상상': 640,
#   '유치': 641,
#   '촬영': 642,
#   '산': 643,
#   '대한민국': 644,
#   '타임': 645,
#   '아쉬움': 646,
#   '시': 647,
#   '젠': 648,
#   '짓': 649,
#   '식': 650,
#   '짐': 651,
#   '전편': 652,
#   '길': 653,
#   '스타': 654,
#   '묘사': 655,
#   '대작': 656,
#   '메세지': 657,
#   '진지하다': 658,
#   '열': 659,
#   '철학': 660,
#   '작다': 661,
#   '프로': 662,
#   '총': 663,
#   '프로그램': 664,
#   '동화': 665,
#   '그림': 666,
#   '마': 667,
#   '드럽다': 668,
#   '여전하다': 669,
#   '졸라': 670,
#   '전달': 671,
#   '서로': 672,
#   '역할': 673,
#   '실망하다': 674,
#   '유머': 675,
#   '등장': 676,
#   '조연': 677,
#   '전작': 678,
#   '경찰': 679,
#   '나중': 680,
#   '무비': 681,
#   '다행': 682,
#   '소녀': 683,
#   '여': 684,
#   '먼저': 685,
#   '마치': 686,
#   '멍청하다': 687,
#   '살인': 688,
#   '영원하다': 689,
#   '고': 690,
#   '덥다': 691,
#   '흠': 692,
#   '잘생기다': 693,
#   '흔하다': 694,
#   '오': 695,
#   '특유': 696,
#   '약하다': 697,
#   '행동': 698,
#   '환상': 699,
#   '햇': 700,
#   '저런': 701,
#   '통해': 702,
#   '인정': 703,
#   '런가': 704,
#   '노출': 705,
#   '관심': 706,
#   '주의': 707,
#   '지루': 708,
#   '입': 709,
#   '청춘': 710,
#   '군대': 711,
#   '바람': 712,
#   '노': 713,
#   '착하다': 714,
#   '예산': 715,
#   '리메이크': 716,
#   '낚': 717,
#   '황당하다': 718,
#   '정': 719,
#   '미래': 720,
#   '안나': 721,
#   '깊이': 722,
#   '가능하다': 723,
#   '씨': 724,
#   '제작비': 725,
#   '위대하다': 726,
#   '효과': 727,
#   '망작': 728,
#   '영웅': 729,
#   '그닥': 730,
#   '손발': 731,
#   '생애': 732,
#   '인하다': 733,
#   '시도': 734,
#   '외': 735,
#   '케이블': 736,
#   '평생': 737,
#   '다만': 738,
#   '과정': 739,
#   '반': 740,
#   '반개': 741,
#   '용이': 742,
#   '유명하다': 743,
#   '범인': 744,
#   '온': 745,
#   '희망': 746,
#   '형님': 747,
#   '젊다': 748,
#   '채널': 749,
#   '얼': 750,
#   '미소': 751,
#   '잘못': 752,
#   '가끔': 753,
#   '화': 754,
#   '강': 755,
#   '상상력': 756,
#   '능력': 757,
#   '스케일': 758,
#   '다소': 759,
#   '모': 760,
#   '신기하다': 761,
#   '카메라': 762,
#   '존': 763,
#   '결론': 764,
#   '부터': 765,
#   '광고': 766,
#   '설레다': 767,
#   '독립영화': 768,
#   '대충': 769,
#   '생': 770,
#   '단': 771,
#   '자막': 772,
#   '메시지': 773,
#   '대안': 774,
#   '한계': 775,
#   '체': 776,
#   '고민': 777,
#   '슬픔': 778,
#   '고맙다': 779,
#   '부족': 780,
#   '고생': 781,
#   '빠르다': 782,
#   '여성': 783,
#   '네': 784,
#   '원하다': 785,
#   '변하다': 786,
#   '리얼': 787,
#   '줌': 788,
#   '커플': 789,
#   '산만하다': 790,
#   '동생': 791,
#   '이면': 792,
#   '지난': 793,
#   '어린이': 794,
#   '사이': 795,
#   '방': 796,
#   '리뷰': 797,
#   '거지같다': 798,
#   '박수': 799,
#   '아침': 800,
#   '보시': 801,
#   '차': 802,
#   '유': 803,
#   '시청자': 804,
#   '괴물': 805,
#   '자연': 806,
#   '희다': 807,
#   '살짝': 808,
#   '굳이': 809,
#   '흐름': 810,
#   '로맨틱': 811,
#   '짱짱': 812,
#   '범죄': 813,
#   '밤': 814,
#   '폭력': 815,
#   '연애': 816,
#   '개판': 817,
#   '포장': 818,
#   '게이': 819,
#   '발견': 820,
#   '심심하다': 821,
#   '빨': 822,
#   '진정': 823,
#   '영환': 824,
#   '수도': 825,
#   '악역': 826,
#   '왠만하다': 827,
#   '몸매': 828,
#   '멋': 829,
#   '어찌': 830,
#   '주기': 831,
#   '덕분': 832,
#   '혹시': 833,
#   '포기': 834,
#   '달': 835,
#   '감탄': 836,
#   '진실': 837,
#   '표절': 838,
#   '일상': 839,
#   '시선': 840,
#   '쓰래': 841,
#   '사극': 842,
#   '조폭': 843,
#   '치': 844,
#   '인기': 845,
#   '웬만하다': 846,
#   '랄': 847,
#   '문화': 848,
#   '정서': 849,
#   '성인': 850,
#   '우정': 851,
#   '표': 852,
#   '대의': 853,
#   '과연': 854,
#   '젤': 855,
#   '남녀': 856,
#   '우울하다': 857,
#   '상처': 858,
#   '더하다': 859,
#   '깔끔하다': 860,
#   '뜻': 861,
#   '퀄리티': 862,
#   '암': 863,
#   '쩐다': 864,
#   '불': 865,
#   '끼리': 866,
#   '로서': 867,
#   '유일하다': 868,
#   '홍콩': 869,
#   '성도': 870,
#   '스': 871,
#   '용서': 872,
#   '특별하다': 873,
#   '순': 874,
#   '오락': 875,
#   '심': 876,
#   '이연걸': 877,
#   '죄': 878,
#   '막판': 879,
#   '하루': 880,
#   '코드': 881,
#   '홍보': 882,
#   '크게': 883,
#   '볼거리': 884,
#   '섹스': 885,
#   '말로': 886,
#   '뮤지컬': 887,
#   '국민': 888,
#   '일이': 889,
#   '정치': 890,
#   '보라': 891,
#   '이기': 892,
#   '어제': 893,
#   '간': 894,
#   '느와르': 895,
#   '빛': 896,
#   '싫어하다': 897,
#   '난해하다': 898,
#   '만큼': 899,
#   '등장인물': 900,
#   '원': 901,
#   '해피엔딩': 902,
#   '북한': 903,
#   '보아': 904,
#   '핵': 905,
#   '펑펑': 906,
#   '힐링': 907,
#   '자식': 908,
#   '희생': 909,
#   '첨': 910,
#   '무협': 911,
#   '나머지': 912,
#   '감명': 913,
#   '끌': 914,
#   '형편': 915,
#   '첫': 916,
#   '지도': 917,
#   '눈빛': 918,
#   '반성': 919,
#   '불가': 920,
#   '무겁다': 921,
#   '자유': 922,
#   '남편': 923,
#   '본방': 924,
#   '당연하다': 925,
#   '다큐멘터리': 926,
#   '딱하다': 927,
#   '차이': 928,
#   '춤': 929,
#   '공부': 930,
#   '기술': 931,
#   '개도': 932,
#   '안좋다': 933,
#   '불쾌하다': 934,
#   '뜬금': 935,
#   '열정': 936,
#   '행복': 937,
#   '실감': 938,
#   '올해': 939,
#   '소장': 940,
#   '늘': 941,
#   '기본': 942,
#   '싸움': 943,
#   '노답': 944,
#   '대화': 945,
#   '쫌': 946,
#   '제로': 947,
#   '의문': 948,
#   '입장': 949,
#   '기적': 950,
#   '무시': 951,
#   '비극': 952,
#   '찡하다': 953,
#   '비주': 954,
#   '불구': 955,
#   '뭐임': 956,
#   '따위': 957,
#   '가면': 958,
#   '느리다': 959,
#   '종교': 960,
#   '그다지': 961,
#   '디즈니': 962,
#   '긴장': 963,
#   '색다르다': 964,
#   '싸구려': 965,
#   '지구': 966,
#   '좀더': 967,
#   '결과': 968,
#   '시사회': 969,
#   '실력': 970,
#   '대가': 971,
#   '악당': 972,
#   '호러': 973,
#   '부끄럽다': 974,
#   '아픔': 975,
#   '아줌마': 976,
#   '적절하다': 977,
#   '게다가': 978,
#   '이제야': 979,
#   '동물': 980,
#   '반복': 981,
#   '본인': 982,
#   '촌스럽다': 983,
#   '강렬하다': 984,
#   '아련하다': 985,
#   '인지': 986,
#   '발전': 987,
#   '러닝': 988,
#   '완전하다': 989,
#   '밥': 990,
#   '방금': 991,
#   '아이돌': 992,
#   '단지': 993,
#   '존경': 994,
#   '하하': 995,
#   '빡치다': 996,
#   '짠하다': 997,
#   '분노': 998,
#   '여행': 999,
#   '인': 1000,
#   ...},
#  40014)

# %%
# Sequence 만들기 / Padding하기 - train, test 모두 
training_sequences  = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, 
                                padding=padding_type, truncating=truct_type)


testing_sequences  = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, 
                                padding=padding_type, truncating=truct_type)

# %% [markdown]
# ## Word2Vec weight 만들기

# %%
ko_model

# %%
len(tokenizer.index_word)
# Out:
# 40014

# %%
import numpy as np

VOCAB_SIZE = len(tokenizer.index_word) + 1
EMBEDDING_DIM = 200

embedding_matrix = np.zeros((VOCAB_SIZE, EMBEDDING_DIM))

# tokenizer에 있는 단어 사전을 순회하면서 word2vec의 200차원 vector를 가져오기
for word, idx in tokenizer.word_index.items():
    embedding_vector = ko_model[word] if word in ko_model else None
    if embedding_vector is not None:
        embedding_matrix[idx] = embedding_vector
        
embedding_matrix.shape
# Out:
# C:\Users\User\anaconda3\envs\nlp\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users
#         0.57009852, -0.25236714,  1.538589  , -0.20186408,  0.15322793,
#        -0.09332677, -0.37294033,  1.14180744, -1.02544713, -0.36533278,
#        -0.01202002, -0.41665232, -0.59812093, -0.63845223, -0.36218691,
#         1.84820664,  0.69762963, -1.080145  , -1.0401994 ,  0.3541005 ,
#        -0.05727062, -0.70051324, -1.02297199,  0.14561783, -0.17227724,
#        -0.66721731, -0.15351965, -0.12619644, -0.14825901,  0.90405506,
#        -1.17667735,  0.03866967, -0.78964615, -0.11472937,  0.88905376,
#        -0.57539517,  0.17546913,  0.35434532, -0.452573  ,  0.01550079,
#        -0.82413119,  1.16270375, -0.392777  ,  0.08164232,  0.60300821,
#        -0.77959961,  2.22155309,  0.05683346, -0.76498526,  0.74309766,
#         1.2266463 , -0.02246751,  1.29709649, -0.75606471,  1.00340676,
#        -0.45882082, -0.09042309, -0.01749961, -1.04276073,  0.6032626 ])

# %% [markdown]
# ## 모델링

# %%
# 모델링  - L2 추가 
embedding_dim = 200
filter_sizes = (3, 4, 5)
num_filters = 100
dropout = 0.5
hidden_dims = 100
max_length = 40

conv_blocks =[]
input_shape = (30)
model_input = tf.keras.layers.Input(shape=input_shape)
z = model_input
for sz in filter_sizes:
    embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length,
                                         weights = [embedding_matrix], trainable = False)(z)
    conv = tf.keras.layers.Conv1D(filters=num_filters,
                         kernel_size=sz,
                         padding="valid",
                         activation="relu",
                         strides=1)(embedding)
    conv = tf.keras.layers.GlobalAveragePooling1D()(conv)
    conv = tf.keras.layers.Flatten()(conv)
    conv_blocks.append(conv)
z = tf.keras.layers.Concatenate()(conv_blocks) if len(conv_blocks) > 1 else conv_blocks[0]

z = tf.keras.layers.Dense(hidden_dims, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.003), bias_regularizer=tf.keras.regularizers.l2(0.003))(z)
z = tf.keras.layers.Dropout(dropout)(z)
model_output = tf.keras.layers.Dense(1, activation="sigmoid")(z)
model = tf.keras.Model(model_input, model_output)

# %%
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 30, 200)      8003000     input_2[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 30, 200)      8003000     input_2[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 30, 200)      8003000     input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 28, 100)      60100       embedding_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 27, 100)      80100       embedding_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 26, 100)      100100      embedding_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_3 (Glo (None, 100)          0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_4 (Glo (None, 100)          0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_5 (Glo (None, 100)          0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 100)          0           global_average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 100)          0           global_average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_5 (Flatten)             (None, 100)          0           global_average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 300)          0           flatten_3[0][0]
#                                                                  flatten_4[0][0]
#                                                                  flatten_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          30100       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 100)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            101         dropout_1[0][0]
# ==================================================================================================
# Total params: 24,279,501
# Trainable params: 270,501
# Non-trainable params: 24,009,000
# __________________________________________________________________________________________________

# %%
# 모델 컴파일 
batch_size = 50
num_epochs = 10
min_word_count = 1
context = 10

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# model training 
num_epochs = 10
early_stopping=tf.keras.callbacks.EarlyStopping(patience=2)
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), callbacks=[early_stopping])
# Out:
# Epoch 1/10
# 4556/4556 [==============================] - 106s 23ms/step - loss: 0.4536 - accuracy: 0.8018 - val_loss: 0.4199 - val_accuracy: 0.8095
# Epoch 2/10
# 4556/4556 [==============================] - 102s 22ms/step - loss: 0.4219 - accuracy: 0.8122 - val_loss: 0.4106 - val_accuracy: 0.8153
# Epoch 3/10
# 4556/4556 [==============================] - 101s 22ms/step - loss: 0.4117 - accuracy: 0.8168 - val_loss: 0.4090 - val_accuracy: 0.8161
# Epoch 4/10
# 4556/4556 [==============================] - 96s 21ms/step - loss: 0.4037 - accuracy: 0.8214 - val_loss: 0.4050 - val_accuracy: 0.8178
# Epoch 5/10
# 4556/4556 [==============================] - 95s 21ms/step - loss: 0.3974 - accuracy: 0.8248 - val_loss: 0.4024 - val_accuracy: 0.8204
# Epoch 6/10
# 4556/4556 [==============================] - 101s 22ms/step - loss: 0.3925 - accuracy: 0.8287 - val_loss: 0.4039 - val_accuracy: 0.8203
# Epoch 7/10
# 4556/4556 [==============================] - 100s 22ms/step - loss: 0.3868 - accuracy: 0.8315 - val_loss: 0.4063 - val_accuracy: 0.8174

# %%
def plot_graphs(history, string, name='model'):
    plt.plot(history.history[string])
    plt.plot(history.history['val_' + string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.title(name)
    plt.legend([string, 'val_' + string])
    plt.draw()
    fig = plt.gcf()
    ##저장될 폴더생성
    result_dir = './result_file'
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
    fig.savefig(result_dir+'/{}.png'.format(name), dpi = fig.dpi)
    print('<{}.png> result_file폴더에 결과 그래프 저장 완료'.format(name))

# %%
import os

# %%
plot_graphs(history, 'accuracy', name = 'model2')
# 'loss'
# Out:
# <model2.png> result_file폴더에 결과 그래프 저장 완료

# %%
    # 모델링  - L2 추가 
def model_2():
     embedding_dim = 200
     filter_sizes = (3, 4, 5)
     num_filters = 100
     dropout = 0.5
     hidden_dims = 100
     max_length = 40

     conv_blocks =[]
     input_shape = (30)
     model_input = tf.keras.layers.Input(shape=input_shape)
     z = model_input
     for sz in filter_sizes:
         embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length,
                                             weights = [embedding_matrix], trainable = False)(z)
         conv = tf.keras.layers.Conv1D(filters=num_filters,
                             kernel_size=sz,
                             padding="valid",
                             activation="relu",
                             strides=1)(embedding)
         conv = tf.keras.layers.GlobalAveragePooling1D()(conv)
         conv = tf.keras.layers.Flatten()(conv)
         conv_blocks.append(conv)
     z = tf.keras.layers.Concatenate()(conv_blocks) if len(conv_blocks) > 1 else conv_blocks[0]

     z = tf.keras.layers.Dense(hidden_dims, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.003), bias_regularizer=tf.keras.regularizers.l2(0.003))(z)
     z = tf.keras.layers.Dropout(dropout)(z)
     model_output = tf.keras.layers.Dense(1, activation="sigmoid")(z)
     model = tf.keras.Model(model_input, model_output)
     
     return model

# %%
model_2().summary()
# Out:
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 30, 200)      8003000     input_4[0][0]
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 30, 200)      8003000     input_4[0][0]
# __________________________________________________________________________________________________
# embedding_11 (Embedding)        (None, 30, 200)      8003000     input_4[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 28, 100)      60100       embedding_9[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 27, 100)      80100       embedding_10[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 26, 100)      100100      embedding_11[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_9 (Glo (None, 100)          0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_10 (Gl (None, 100)          0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_11 (Gl (None, 100)          0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 100)          0           global_average_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 100)          0           global_average_pooling1d_10[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 100)          0           global_average_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 300)          0           flatten_9[0][0]
#                                                                  flatten_10[0][0]
#                                                                  flatten_11[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 100)          30100       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 100)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            101         dropout_3[0][0]
# ==================================================================================================
# Total params: 24,279,501
# Trainable params: 270,501
# Non-trainable params: 24,009,000
# __________________________________________________________________________________________________
