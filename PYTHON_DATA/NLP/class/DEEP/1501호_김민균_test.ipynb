# %% [markdown]
# ## 1번 문제

# %%
a = [2,1,0]
#편의를 위해 2에 자리에서 반올림
import numpy as np

def softmax(L):
    ex = np.exp(L)
    sum_exp = sum(ex)
    result = []
    for i in range(len(L)):
        result.append((ex[i]/sum_exp).round(2))
    return result

# %%
softmax(a)
# Out:
# [0.67, 0.24, 0.09]

# %% [markdown]
# ## 2번 문제

# %%
d_error = y - output

# %% [markdown]
# ## 3번 문제

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


sentences = ['바나나 사과 포도 포도', '사과 포도', '포도 바나나', '짜장면 짬뽕 탕수육', '볶음밥 탕수육',
             '짜장면 짬뽕', '라면 스시', '스시','가츠동 스시 소바', '된장찌개 김치찌개 김치', '김치 된장', '비빔밥 김치']

# %%
tokenizer = Tokenizer(oov_token = "<OOV>")

# %%
tokenizer.fit_on_texts(sentences)
tokenizer.word_index
# Out:
# {'<OOV>': 1,
#  '가츠동': 12,
#  '김치': 4,
#  '김치찌개': 15,
#  '된장': 16,
#  '된장찌개': 14,
#  '라면': 11,
#  '바나나': 5,
#  '볶음밥': 10,
#  '비빔밥': 17,
#  '사과': 6,
#  '소바': 13,
#  '스시': 3,
#  '짜장면': 7,
#  '짬뽕': 8,
#  '탕수육': 9,
#  '포도': 2}

# %%
max_len = max([ len(line.split()) for line in sentences])
max_len
# Out:
# 4

# %%
seq = tokenizer.texts_to_sequences(sentences)
padded = pad_sequences(seq, maxlen=max_len, padding = 'post', truncating= 'post')

# %%
padded # 결과적으로 나온 sequecne
# Out:
# array([[ 5,  6,  2,  2],
#        [ 6,  2,  0,  0],
#        [ 2,  5,  0,  0],
#        [ 7,  8,  9,  0],
#        [10,  9,  0,  0],
#        [ 7,  8,  0,  0],
#        [11,  3,  0,  0],
#        [ 3,  0,  0,  0],
#        [12,  3, 13,  0],
#        [14, 15,  4,  0],
#        [ 4, 16,  0,  0],
#        [17,  4,  0,  0]], dtype=int32)

# %% [markdown]
# ## 문제 4번

# %%
from tensorflow.keras.layers import Bidirectional, Dense, LSTM, Dropout, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.activations import softmax, relu
from tensorflow.keras.losses import categorical_crossentropy, sparse_categorical_crossentropy

# %%
model = Sequential()
model.add(Embedding(3211, 100, input_length= 10))
model.add(Bidirectional(LSTM(150, return_sequences=True))) # 답1
model.add(Dropout(0.2))
model.add(LSTM(100))
model.add(Dense(1605, activation = 'relu'))
model.add(Dense(3211, activation = 'softmax')) # 답2
model.compile(loss = 'categorical_crossentropy', optimizer= 'adam', metrics = ['accuracy']) # 답3
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_8 (Embedding)      (None, 10, 100)           321100
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, 10, 300)           301200
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 10, 300)           0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 100)               160400
# _________________________________________________________________
# dense_11 (Dense)             (None, 1605)              162105
# _________________________________________________________________
# dense_12 (Dense)             (None, 3211)              5156866
# ...
# Total params: 6,101,671
# Trainable params: 6,101,671
# Non-trainable params: 0
# ...
